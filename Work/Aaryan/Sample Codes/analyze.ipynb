# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the CSV file and create a dataframe
df = pd.read_csv(r'C:\Users\pilug\Documents\DNN-CFFs\Work\Aaryan\Sample Codes\average_values_from_replicas.csv')

# Display the dataframe
df
# Out:
#          ReH       ReE      ReHt      dvcs  AbsRes_ReH  AbsRes_ReE  \
# 0  -0.150993 -0.495047  0.013040  0.015295    0.961586    0.185047
# 1  -0.317168 -0.547831  0.033282  0.015295    0.795412    0.237831
# 2  -0.121563 -0.493865 -0.108875  0.015295    0.991016    0.183865
# 3  -0.190271 -0.733537  0.024709  0.015295    0.922308    0.423537
# 4  -0.094462 -0.818551  0.093201  0.015295    1.018118    0.508551
# 5  -0.140498 -0.582749 -0.187027  0.015295    0.972081    0.272749
# 6  -0.118810 -0.519276  0.043266  0.015295    0.993769    0.209276
# 7  -0.172681 -0.542552  0.018067  0.015295    0.939898    0.232552
# 8  -0.211707 -0.711234  0.035685  0.015295    0.900872    0.401234
# 9  -0.091315 -0.527081  0.063759  0.015295    1.021264    0.217081
# 10 -0.108880 -0.509591 -0.037197  0.015295    1.003700    0.199591
# 11 -0.171505 -0.742462 -0.108346  0.015295    0.941075    0.432462
# 12 -0.150490 -0.685414  0.028446  0.015295    0.962089    0.375414
# ...

# %%
def get_res(i):
    # Get the first 24 rows of the dataframe
    df_subset = df.iloc[24 * i:24 * (i + 1)]

    # Calculate the average of the first three columns
    average_values = df_subset.iloc[:, :3].mean()

    # Print the result
    print(average_values)

# %%
get_res(0)
get_res(1)
# Out:
# ReH    -0.150053
# ReE    -0.615054
# ReHt    0.001884
# dtype: float64
# ReH    -0.131689
# ReE    -0.561643
# ReHt   -0.003973
# dtype: float64

# %%
-0.99	-0.31	-0.4
